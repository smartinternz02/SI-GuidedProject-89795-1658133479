# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import json

# %%
import matplotlib.pyplot as plt

# %%
import pickle

# %%
from wordcloud import WordCloud

# %%
from ast import literal_eval

# %%
credits=pd.read_csv(r"C:\Users\hi\Downloads\tmdb_5000_credits.csv")

# %%
movies_df=pd.read_csv(r"C:\Users\hi\Downloads\tmdb_5000_credits.csv")

# %%
credits.head()
# Out:
#   movie_id                                     title  \
# 0    19995                                    Avatar
# 1      285  Pirates of the Caribbean: At World's End
# 2   206647                                   Spectre
# 3    49026                     The Dark Knight Rises
# 4    49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew Unnamed: 4 Unnamed: 5  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...        NaN        NaN
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...        NaN        NaN
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...        NaN        NaN
# ...

# %%
movies_df.head()
# Out:
#   movie_id                                     title  \
# 0    19995                                    Avatar
# 1      285  Pirates of the Caribbean: At World's End
# 2   206647                                   Spectre
# 3    49026                     The Dark Knight Rises
# 4    49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew Unnamed: 4 Unnamed: 5  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...        NaN        NaN
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...        NaN        NaN
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...        NaN        NaN
# ...

# %%
credits.tail()
# Out:
#      movie_id                      title  \
# 4808     9367                El Mariachi
# 4809    72766                  Newlyweds
# 4810   231617  Signed, Sealed, Delivered
# 4811   126186           Shanghai Calling
# 4812    25975          My Date with Drew
#
#                                                    cast  \
# 4808  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4809  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4810  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4811  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4812  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew Unnamed: 4 Unnamed: 5  \
# 4808  [{"credit_id": "52fe44eec3a36847f80b280b", "de...        NaN        NaN
# 4809  [{"credit_id": "52fe487dc3a368484e0fb013", "de...        NaN        NaN
# 4810  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...        NaN        NaN
# ...

# %%
print("credits:",credits.columns)
print("movie_df:",movies_df.columns)
# Out:
# credits: Index(['movie_id', 'title', 'cast', 'crew', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 1255', 'Unnamed: 1256', 'Unnamed: 1257', 'Unnamed: 1258',
#        'Unnamed: 1259', 'Unnamed: 1260', 'Unnamed: 1261', 'Unnamed: 1262',
#        'Unnamed: 1263', 'Unnamed: 1264'],
#       dtype='object', length=1265)
# movie_df: Index(['movie_id', 'title', 'cast', 'crew', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 1255', 'Unnamed: 1256', 'Unnamed: 1257', 'Unnamed: 1258',
#        'Unnamed: 1259', 'Unnamed: 1260', 'Unnamed: 1261', 'Unnamed: 1262',
#        'Unnamed: 1263', 'Unnamed: 1264'],
#       dtype='object', length=1265)

# %%
print("credits:",credits.shape)
print("movie_df:",movies_df.shape)
# Out:
# credits: (4813, 1265)
# movie_df: (4813, 1265)

# %%
credits_column_renamed=credits.rename(index=str,columns={"movie_id":"id"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13512/3988700326.py in <module>
# ----> 1 credits_column_renamed=credits.rename(index=str,columns={"movie_id":"id"})
#
# AttributeError: '_Printer' object has no attribute 'rename'

# %% [raw]
# credits_column_renamed

# %%
movies=movies_df.merge(credits_column_renamed,on="id")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6584/3669671483.py in <module>
# ----> 1 movies=movies_df.merge(credits_column_renamed,on="id")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9188         from pandas.core.reshape.merge import merge
#    9189
# -> 9190         return merge(
#    9191             self,
#    9192             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ...

# %%
movies.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6584/3378948203.py in <module>
# ----> 1 movies.shape
#
# NameError: name 'movies' is not defined

# %%
movies.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6584/167274070.py in <module>
# ----> 1 movies.info()
#
# NameError: name 'movies' is not defined

# %%
movies.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6584/2013316916.py in <module>
# ----> 1 movies.describe()
#
# NameError: name 'movies' is not defined
